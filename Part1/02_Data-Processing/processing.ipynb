# %%
import pandas as pd
import numpy as np

# %%
titanic_df = pd.read_csv("titanic.csv")

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill in missing "Age" values
titanic_df["Age"].fillna(titanic_df["Age"].mean(), inplace=True)
# Out:
# /var/folders/gt/yv99s70x75l99bc9w9hl7w840000gn/T/ipykernel_10147/2851142508.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic_df["Age"].fillna(titanic_df["Age"].mean(), inplace=True)

# %%
# Delete rows with misisng "Embarked" values
criteria = titanic_df["Embarked"].isnull()
titanic_df = titanic_df[~criteria]

# %%
# Dropping irrelevant columns
titanic_df = titanic_df.drop(["Cabin", "Ticket", "PassengerId", "SibSp", "Parch"], axis=1)

# %%
titanic_df["Sex"].isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import OrdinalEncoder

# Encoding "Age" values
encoder = OrdinalEncoder(categories=[['female', 'male']])

titanic_df[["Sex"]] = encoder.fit_transform(titanic_df[["Sex"]])

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris  1.0
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0
# 2           1       3                             Heikkinen, Miss. Laina  0.0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0
# 4           0       3                           Allen, Mr. William Henry  1.0
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas  1.0
# 887         1       1                       Graham, Miss. Margaret Edith  0.0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"  0.0
# 889         1       1                              Behr, Mr. Karl Howell  1.0
# 890         0       3                                Dooley, Mr. Patrick  1.0
#
#            Age     Fare Embarked
# 0    22.000000   7.2500        S
# 1    38.000000  71.2833        C
# 2    26.000000   7.9250        S
# 3    35.000000  53.1000        S
# 4    35.000000   8.0500        S
# ..         ...      ...      ...
# 886  27.000000  13.0000        S
# 887  19.000000  30.0000        S
# 888  29.699118  23.4500        S
# 889  26.000000  30.0000        C
# 890  32.000000   7.7500        Q
#
# [889 rows x 7 columns]

# %%
titanic_df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

# Encoding "Embarked" values
encoder = OneHotEncoder()

embarked = encoder.fit_transform(titanic_df[["Embarked"]]).toarray()

titanic_df[["C", "S", "Q"]] = embarked

# %%
titanic_df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris  1.0
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  0.0
# 2           1       3                             Heikkinen, Miss. Laina  0.0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.0
# 4           0       3                           Allen, Mr. William Henry  1.0
# ..        ...     ...                                                ...  ...
# 886         0       2                              Montvila, Rev. Juozas  1.0
# 887         1       1                       Graham, Miss. Margaret Edith  0.0
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"  0.0
# 889         1       1                              Behr, Mr. Karl Howell  1.0
# 890         0       3                                Dooley, Mr. Patrick  1.0
#
#            Age     Fare Embarked    C    S    Q
# 0    22.000000   7.2500        S  0.0  0.0  1.0
# 1    38.000000  71.2833        C  1.0  0.0  0.0
# 2    26.000000   7.9250        S  0.0  0.0  1.0
# 3    35.000000  53.1000        S  0.0  0.0  1.0
# 4    35.000000   8.0500        S  0.0  0.0  1.0
# ..         ...      ...      ...  ...  ...  ...
# 886  27.000000  13.0000        S  0.0  0.0  1.0
# 887  19.000000  30.0000        S  0.0  0.0  1.0
# 888  29.699118  23.4500        S  0.0  0.0  1.0
# 889  26.000000  30.0000        C  1.0  0.0  0.0
# 890  32.000000   7.7500        Q  0.0  1.0  0.0
#
# [889 rows x 10 columns]

# %%
# Combining the csv files
titanic_df.to_csv("processed.csv", index=False)
